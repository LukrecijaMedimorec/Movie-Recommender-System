# %% [markdown]
# # Data preprocessing

# %%
import pandas as pd
import numpy as np 
import ast
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
movies_df=pd.read_csv('./data/movies_metadata.csv')
def has_special_char(s):
    regex_pattern = r'[^a-zA-Z0-9\s]'
    return bool(pd.Series(s).str.contains(regex_pattern).any())
# Out:
# /tmp/ipykernel_126519/3765895067.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies_df=pd.read_csv('./data/movies_metadata.csv')

# %%
mask1 = movies_df['imdb_id']=='0'
mask2 = movies_df['id'] == '0'
mask3 = movies_df['id'].apply(has_special_char)
mask4 = movies_df['title'] == 'NaN'
mask = mask1 | mask2 | mask3 | mask4 
res_rows = movies_df[mask]

mask = ~mask
movies_df = movies_df[mask]
movies_df['id']=movies_df['id'].astype(int)

# %%
movies_df['description'] = movies_df['tagline'] + movies_df['overview']
movies_df['description'] = movies_df['description'].fillna('')

mask = movies_df['description'] == ''
mask = ~mask
movies_df = movies_df[mask]

# %%
keywords_df = pd.read_csv('./data/keywords.csv')
keywords_df = keywords_df.drop_duplicates(subset=['id'])

# %%
movies_df=movies_df.merge(keywords_df, on='id', how='inner')
movies_df = movies_df.drop_duplicates(subset=['id'])

# %%
specified_column = 'title'

duplicates = movies_df[movies_df.duplicated(subset=[specified_column], keep=False)]

selected_columns = ['id', 'title', 'description', 'genres', 'keywords', 'release_date']
result = duplicates[selected_columns].sort_values(by='title')
display(result)

# %%
movies_df['genres'] = movies_df['genres'].apply(ast.literal_eval)
movies_df['genres'] = movies_df['genres'].apply(lambda genres: [genre['name'] for genre in genres])

movies_df['keywords'] = movies_df['keywords'].apply(ast.literal_eval)
movies_df['keywords'] = movies_df['keywords'].apply(lambda keywords: [keyword['name'] for keyword in keywords])

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

def preprocess_description(description):
    if isinstance(description, str):
        tokens = word_tokenize(description.lower())
        stop_words = set(stopwords.words('english'))
        filtered_tokens = [word for word in tokens if word.isalnum() and word not in stop_words]
        lemmatizer = WordNetLemmatizer()
        lemmatized_tokens = [lemmatizer.lemmatize(word) for word in filtered_tokens]
        preprocessed_description = ' '.join(lemmatized_tokens)
        return preprocessed_description
    else:
        return ''
    
movies_df['preprocessed_description'] = movies_df['description'].apply(preprocess_description)
# Out:
# [nltk_data] Downloading package punkt to /home/lukrecija/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/lukrecija/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/lukrecija/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
mask = movies_df['preprocessed_description'] == ''
mask = ~mask
movies_df = movies_df[mask]

# %%
movies_df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False                                                NaN  65000000
# 1  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 2  False                                                NaN  16000000
# 3  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 4  False                                                NaN  60000000
#
#                              genres homepage     id    imdb_id  \
# 0      [Adventure, Fantasy, Family]      NaN   8844  tt0113497
# 1                 [Romance, Comedy]      NaN  15602  tt0113228
# 2          [Comedy, Drama, Romance]      NaN  31357  tt0114885
# 3                          [Comedy]      NaN  11862  tt0113041
# 4  [Action, Crime, Drama, Thriller]      NaN    949  tt0113277
#
#   original_language               original_title  \
# 0                en                      Jumanji
# 1                en             Grumpier Old Men
# 2                en            Waiting to Exhale
# 3                en  Father of the Bride Part II
# 4                en                         Heat
#
#                                             overview  ...  \
# 0  When siblings Judy and Peter discover an encha...  ...
# 1  A family wedding reignites the ancient feud be...  ...
# 2  Cheated on, mistreated and stepped on, the wom...  ...
# 3  Just when George Banks has recovered from his ...  ...
# 4  Obsessive master thief, Neil McCauley leads a ...  ...
#
#                                     spoken_languages    status  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 1           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
#
#                                              tagline  \
# 0          Roll the dice and unleash the excitement!
# 1  Still Yelling. Still Fighting. Still Ready for...
# 2  Friends are the people who let you be yourself...
# 3  Just When His World Is Back To Normal... He's ...
# 4                           A Los Angeles Crime Saga
#
#                          title  video  vote_average  vote_count  \
# 0                      Jumanji  False           6.9      2413.0
# 1             Grumpier Old Men  False           6.5        92.0
# 2            Waiting to Exhale  False           6.1        34.0
# 3  Father of the Bride Part II  False           5.7       173.0
# 4                         Heat  False           7.7      1886.0
#
#                                          description  \
# 0  Roll the dice and unleash the excitement!When ...
# 1  Still Yelling. Still Fighting. Still Ready for...
# 2  Friends are the people who let you be yourself...
# 3  Just When His World Is Back To Normal... He's ...
# 4  A Los Angeles Crime SagaObsessive master thief...
#
#                                             keywords  \
# 0  [board game, disappearance, based on children'...
# 1  [fishing, best friend, duringcreditsstinger, o...
# 2  [based on novel, interracial relationship, sin...
# 3  [baby, midlife crisis, confidence, aging, daug...
# 4  [robbery, detective, bank, obsession, chase, s...
#
#                             preprocessed_description
# 0  roll dice unleash excitement sibling judy pete...
# 1  still yelling still fighting still ready famil...
# 2  friend people let never let forget mistreated ...
# 3  world back normal surprise life george bank re...
# 4  los angeles crime sagaobsessive master thief n...
#
# [5 rows x 27 columns]

# %%
empty_keywords_rows = movies_df[movies_df['keywords'].apply(lambda x: len(x) == 0)]

empty_keywords_ids = empty_keywords_rows['id']
display(empty_keywords_rows)
# Out:
#        adult belongs_to_collection budget  \
# 6      False                   NaN      0
# 41     False                   NaN      0
# 51     False                   NaN      0
# 73     False                   NaN      0
# 81     False                   NaN      0
# ...      ...                   ...    ...
# 20389  False                   NaN      0
# 20390  False                   NaN      0
# 20393  False                   NaN      0
# 20399  False                   NaN      0
# 20403  False                   NaN      0
#
#                                                   genres homepage      id  \
# 6                     [Action, Adventure, Drama, Family]      NaN   45325
# 41                             [Action, Thriller, Drama]      NaN  117164
# 51                                       [Drama, Family]      NaN   40628
# 73     [Action, Adventure, Drama, Science Fiction, Th...      NaN   45549
# 81                                         [Documentary]      NaN   89333
# ...                                                  ...      ...     ...
# 20389                           [Comedy, Drama, Romance]      NaN  174271
# 20390                                   [Comedy, Horror]      NaN   65416
# 20393                [Action, Mystery, Thriller, Horror]      NaN   45527
# 20399                                    [Comedy, Drama]      NaN  420346
# 20403                          [Action, Drama, Thriller]      NaN   67758
#
#          imdb_id original_language  \
# 6      tt0112302                en
# 41     tt0109950                en
# 51     tt0114753                en
# 73     tt0111173                en
# 81     tt0112646                en
# ...          ...               ...
# 20389  tt0116345                en
# 20390  tt0251582                en
# 20393  tt1331329                en
# 20399  tt4130180                en
# 20403  tt0303758                en
#
#                                       original_title  \
# 6                                       Tom and Huck
# 41                                    Guardian Angel
# 51                                          Two Bits
# 73                                          Shopping
# 81                                           Catwalk
# ...                                              ...
# 20389  The Fortunes and Misfortunes of Moll Flanders
# 20390                      An American Vampire Story
# 20393                                The Final Storm
# 20399                              The Morning After
# 20403                                       Betrayal
#
#                                                 overview  ...  \
# 6      A mischievous young boy, Tom Sawyer, witnesses...  ...
# 41     Detective - turned - bodyguard Cynthia McKay (...  ...
# 51     It's a hot summer day in 1933 in South Philly,...  ...
# 73     A dark, hip, urban story of a barren and anony...  ...
# 81     A documentary following Christy Turlington and...  ...
# ...                                                  ...  ...
# 20389  In her filthy cell in Newgate prison Moll Flan...  ...
# 20390  A group of friends go on a vacation with some ...  ...
# 20393  A stranger named Silas flees from a devastatin...  ...
# 20399  The Morning After is a feature film that consi...  ...
# 20403  When one of her hits goes wrong, a professiona...  ...
#
#                                         spoken_languages    status  \
# 6      [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 41                                                    []  Released
# 51              [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 73              [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 81              [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...                                                  ...       ...
# 20389  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 20390           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 20393           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 20399           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 20403           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 6                                 The Original Bad Boys.
# 41                              She's no angel of mercy.
# 51     You're never too old to believe in a dream. Or...
# 73                       No one leaves without paying...
# 81     The moment when fashion, art and entertainment...
# ...                                                  ...
# 20389                  Notorius Scandalous Unforgettable
# 20390                          You're not going anywhere
# 20393                                     Action, Horror
# 20399                          What happened last night?
# 20403                             A deadly game of wits.
#
#                                                title  video  vote_average  \
# 6                                       Tom and Huck  False           5.4
# 41                                    Guardian Angel  False           6.3
# 51                                          Two Bits  False           5.4
# 73                                          Shopping  False           5.6
# 81                                           Catwalk  False           7.0
# ...                                              ...    ...           ...
# 20389  The Fortunes and Misfortunes of Moll Flanders  False           5.8
# 20390                      An American Vampire Story  False           4.5
# 20393                                The Final Storm  False           3.7
# 20399                              The Morning After  False           4.0
# 20403                                       Betrayal  False           3.8
#
#        vote_count                                        description keywords  \
# 6            45.0  The Original Bad Boys.A mischievous young boy,...       []
# 41            3.0  She's no angel of mercy.Detective - turned - b...       []
# 51           11.0  You're never too old to believe in a dream. Or...       []
# 73           13.0  No one leaves without paying...A dark, hip, ur...       []
# 81            2.0  The moment when fashion, art and entertainment...       []
# ...           ...                                                ...      ...
# 20389         8.0  Notorius Scandalous UnforgettableIn her filthy...       []
# 20390         4.0  You're not going anywhereA group of friends go...       []
# 20393        11.0  Action, HorrorA stranger named Silas flees fro...       []
# 20399         2.0  What happened last night?The Morning After is ...       []
# 20403         6.0  A deadly game of wits.When one of her hits goe...       []
#
#                                 preprocessed_description
# 6      original bad mischievous young boy tom sawyer ...
# 41     angel turned bodyguard cynthia mckay cynthia r...
# 51     never old believe dream young make one come tr...
# 73     one leaf without paying dark hip urban story b...
# 81     moment fashion art entertainment come together...
# ...                                                  ...
# 20389  notorius scandalous unforgettablein filthy cel...
# 20390  going anywherea group friend go vacation new f...
# 20393  action horrora stranger named silas flees deva...
# 20399  happened last night morning feature film consi...
# 20403  deadly game one hit go wrong professional assa...
#
# [3253 rows x 27 columns]

# %%
def generate_keywords(description):
    if not description:
        return []
    
    vectorizer = TfidfVectorizer(stop_words=list(ENGLISH_STOP_WORDS))
    X = vectorizer.fit_transform([description])
    keywords = list(vectorizer.get_feature_names_out())
    keywords = [word for word in keywords if not any(char.isdigit() for char in word)]
    return keywords[:6]

mask = movies_df['keywords'].apply(lambda x: len(x) == 0)
movies_df.loc[mask, 'keywords'] = movies_df.loc[mask, 'description'].apply(generate_keywords)
movies_df[movies_df['id'].isin(empty_keywords_ids)].head()
# Out:
#     adult belongs_to_collection budget  \
# 6   False                   NaN      0
# 41  False                   NaN      0
# 51  False                   NaN      0
# 73  False                   NaN      0
# 81  False                   NaN      0
#
#                                                genres homepage      id  \
# 6                  [Action, Adventure, Drama, Family]      NaN   45325
# 41                          [Action, Thriller, Drama]      NaN  117164
# 51                                    [Drama, Family]      NaN   40628
# 73  [Action, Adventure, Drama, Science Fiction, Th...      NaN   45549
# 81                                      [Documentary]      NaN   89333
#
#       imdb_id original_language  original_title  \
# 6   tt0112302                en    Tom and Huck
# 41  tt0109950                en  Guardian Angel
# 51  tt0114753                en        Two Bits
# 73  tt0111173                en        Shopping
# 81  tt0112646                en         Catwalk
#
#                                              overview  ...  \
# 6   A mischievous young boy, Tom Sawyer, witnesses...  ...
# 41  Detective - turned - bodyguard Cynthia McKay (...  ...
# 51  It's a hot summer day in 1933 in South Philly,...  ...
# 73  A dark, hip, urban story of a barren and anony...  ...
# 81  A documentary following Christy Turlington and...  ...
#
#                                      spoken_languages    status  \
# 6   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 41                                                 []  Released
# 51           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 73           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 81           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                               tagline           title  video  \
# 6                              The Original Bad Boys.    Tom and Huck  False
# 41                           She's no angel of mercy.  Guardian Angel  False
# 51  You're never too old to believe in a dream. Or...        Two Bits  False
# 73                    No one leaves without paying...        Shopping  False
# 81  The moment when fashion, art and entertainment...         Catwalk  False
#
#     vote_average  vote_count  \
# 6            5.4        45.0
# 41           6.3         3.0
# 51           5.4        11.0
# 73           5.6        13.0
# 81           7.0         2.0
#
#                                           description  \
# 6   The Original Bad Boys.A mischievous young boy,...
# 41  She's no angel of mercy.Detective - turned - b...
# 51  You're never too old to believe in a dream. Or...
# 73  No one leaves without paying...A dark, hip, ur...
# 81  The moment when fashion, art and entertainment...
#
#                                              keywords  \
# 6    [accused, adventures, alcoholic, bad, boy, boys]
# 41  [accompanies, action, angel, bodyguard, cynthi...
# 51        [act, ailing, believe, business, buy, come]
# 73  [aid, anonymous, arrive, barren, billy, business]
# 81  [art, beauty, christy, come, documentary, ente...
#
#                              preprocessed_description
# 6   original bad mischievous young boy tom sawyer ...
# 41  angel turned bodyguard cynthia mckay cynthia r...
# 51  never old believe dream young make one come tr...
# 73  one leaf without paying dark hip urban story b...
# 81  moment fashion art entertainment come together...
#
# [5 rows x 27 columns]

# %%
movies_df['genres'] = movies_df['genres'].apply(lambda x: str(x).replace('[', '{').replace(']', '}'))

movies_df['keywords'] = movies_df['keywords'].apply(lambda x: str(x).replace('[', '{').replace(']', '}'))

# %%
def remove_single_quotes(x):
    return re.sub(r"(?<![a-zA-Z])'|'(?![a-zA-Z])", "", x) if pd.notnull(x) else x

movies_df['keywords'] = movies_df['keywords'].apply(remove_single_quotes)

# %%
movies_df['keywords'] = movies_df['keywords'].apply(str).str.replace('"', '')

movies_df['genres'] = movies_df['genres'].apply(str).str.replace("'", '')

# %%
movies_df.head(2)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False                                                NaN  65000000
# 1  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
#
#                          genres homepage     id    imdb_id original_language  \
# 0  {Adventure, Fantasy, Family}      NaN   8844  tt0113497                en
# 1             {Romance, Comedy}      NaN  15602  tt0113228                en
#
#      original_title                                           overview  ...  \
# 0           Jumanji  When siblings Judy and Peter discover an encha...  ...
# 1  Grumpier Old Men  A family wedding reignites the ancient feud be...  ...
#
#                                     spoken_languages    status  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 1           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline             title  video  \
# 0          Roll the dice and unleash the excitement!           Jumanji  False
# 1  Still Yelling. Still Fighting. Still Ready for...  Grumpier Old Men  False
#
#    vote_average  vote_count  \
# 0           6.9      2413.0
# 1           6.5        92.0
#
#                                          description  \
# 0  Roll the dice and unleash the excitement!When ...
# 1  Still Yelling. Still Fighting. Still Ready for...
#
#                                             keywords  \
# 0  {board game, disappearance, based on children'...
# 1  {fishing, best friend, duringcreditsstinger, o...
#
#                             preprocessed_description
# 0  roll dice unleash excitement sibling judy pete...
# 1  still yelling still fighting still ready famil...
#
# [2 rows x 27 columns]

# %%
min_vote_count = movies_df[movies_df['vote_count'] > 0]['vote_count'].min()
max_vote_count = movies_df['vote_count'].max()

print(f"Minimum vote_count: {min_vote_count}")
print(f"Maximum vote_count: {max_vote_count}")
# Out:
# Minimum vote_count: 1.0
# Maximum vote_count: 14075.0

# %%
m = movies_df['vote_count'].quantile(0.7) 
C = movies_df['vote_average'].mean()

def calculate_weighted_rating(x, m, C):
    v = x['vote_count']
    R = x['vote_average']
    return (v / (v + m)) * R + (m / (m + v)) * C

movies_df['weighted_rating'] = movies_df.apply(calculate_weighted_rating, args=(m, C), axis=1)

# %%
columns_to_drop=['adult', 'belongs_to_collection', 'budget', 'homepage',
       'original_language', 'original_title', 'overview',
       'popularity',  'production_companies',
       'production_countries', 'revenue', 
       'spoken_languages', 'status', 'tagline', 'video',
       'vote_average', 'vote_count']

movies_df.drop(columns=columns_to_drop, inplace=True)

# %%
movies_df.head()
# Out:
#                              genres     id    imdb_id  \
# 0      {Adventure, Fantasy, Family}   8844  tt0113497
# 1                 {Romance, Comedy}  15602  tt0113228
# 2          {Comedy, Drama, Romance}  31357  tt0114885
# 3                          {Comedy}  11862  tt0113041
# 4  {Action, Crime, Drama, Thriller}    949  tt0113277
#
#                         poster_path release_date  runtime  \
# 0  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg   1995-12-15    104.0
# 1  /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg   1995-12-22    101.0
# 2  /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg   1995-12-22    127.0
# 3  /e64sOI48hQXyru7naBFyssKFxVd.jpg   1995-02-10    106.0
# 4  /zMyfPUelumio3tiDKPffaUpsQTD.jpg   1995-12-15    170.0
#
#                          title  \
# 0                      Jumanji
# 1             Grumpier Old Men
# 2            Waiting to Exhale
# 3  Father of the Bride Part II
# 4                         Heat
#
#                                          description  \
# 0  Roll the dice and unleash the excitement!When ...
# 1  Still Yelling. Still Fighting. Still Ready for...
# 2  Friends are the people who let you be yourself...
# 3  Just When His World Is Back To Normal... He's ...
# 4  A Los Angeles Crime SagaObsessive master thief...
#
#                                             keywords  \
# 0  {board game, disappearance, based on children'...
# 1  {fishing, best friend, duringcreditsstinger, o...
# 2  {based on novel, interracial relationship, sin...
# 3  {baby, midlife crisis, confidence, aging, daug...
# 4  {robbery, detective, bank, obsession, chase, s...
#
#                             preprocessed_description  weighted_rating
# 0  roll dice unleash excitement sibling judy pete...         6.867230
# 1  still yelling still fighting still ready famil...         6.170573
# 2  friend people let never let forget mistreated ...         5.856086
# 3  world back normal surprise life george bank re...         5.710835
# 4  los angeles crime sagaobsessive master thief n...         7.629771

# %%
movies_df.to_csv('./data/preprocessed_data_for_db.csv', index=False)

# %%
movies_df['genres'] = movies_df['genres'].apply(lambda x: str(x).replace('{', '').replace('}', ''))
movies_df['genres'] = movies_df['genres'].apply(lambda x: str(x).replace(',', ''))
movies_df['keywords'] = movies_df['keywords'].apply(lambda x: str(x).replace('{', '').replace('}', ''))

movies_df['features'] = movies_df['genres'] + ' ' + movies_df['preprocessed_description'] + ' ' + movies_df['keywords']
movies_df['features'] = movies_df['features'].fillna('')
movies_df['features'] = movies_df['features'].str.lower()

# %%
movies_df.to_csv('./data/preprocessed_data.csv', index=False)

# %%
ratings = pd.read_csv('./data/ratings_small.csv')

threshold = 3
ratings['binary_rating']=(ratings['rating']>=threshold).astype(int)
ratings.to_csv('./data/ratings.csv', index=False)
